# %%
import numpy as np


list = np.array([23, 45, 67, 32, 56, 78, 43])

print(np.mean(list))

print(np.median(list))

print(np.std(list))

print(np.max(list))

print(np.argmax(list))
# Out:
# 49.142857142857146
# 45.0
# 17.85199925921521
# 78
# 5

# %%
import numpy as np
